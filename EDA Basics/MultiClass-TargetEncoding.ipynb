# %% [markdown]
# # Multiclass Target Encoding

# %%
import pandas as pd
import numpy as np

# %%
np.random.seed(999)
target = list(np.random.randint(0, 3, 20))
footballers = ["Lionel Messi", "Cristiano Ronaldo", "Xavi"]

# %%
np.random.seed(123)
footballers = [footballers[i] for i in np.random.randint(0, len(footballers), 20)]

# %%
df = pd.DataFrame({"footballers" : footballers, "target" : target})
df
# Out:
#           footballers  target
# 0                Xavi       0
# 1   Cristiano Ronaldo       0
# 2                Xavi       1
# 3                Xavi       1
# 4        Lionel Messi       0
# 5                Xavi       1
# 6                Xavi       1
# 7   Cristiano Ronaldo       0
# 8                Xavi       1
# 9   Cristiano Ronaldo       1
# 10               Xavi       0
# 11  Cristiano Ronaldo       0
# 12       Lionel Messi       0
# 13  Cristiano Ronaldo       1
# 14               Xavi       2
# 15  Cristiano Ronaldo       1
# 16       Lionel Messi       0
# 17               Xavi       2
# 18       Lionel Messi       2
# 19  Cristiano Ronaldo       2

# %% [markdown]
# ## 1. Calculating by Mean

# %%
stats = df['target'].groupby(df['footballers']).agg(['count', 'mean'])
stats
# Out:
#                    count      mean
# footballers
# Cristiano Ronaldo      7  0.714286
# Lionel Messi           4  0.500000
# Xavi                   9  1.000000

# %%
df = df.join(stats.drop(columns = 'count'), on = 'footballers', how = 'left').rename(columns = {'mean'  : 'encoded_mean'})
df
# Out:
#           footballers  target  encoded_mean
# 0                Xavi       0      1.000000
# 1   Cristiano Ronaldo       0      0.714286
# 2                Xavi       1      1.000000
# 3                Xavi       1      1.000000
# 4        Lionel Messi       0      0.500000
# 5                Xavi       1      1.000000
# 6                Xavi       1      1.000000
# 7   Cristiano Ronaldo       0      0.714286
# 8                Xavi       1      1.000000
# 9   Cristiano Ronaldo       1      0.714286
# 10               Xavi       0      1.000000
# 11  Cristiano Ronaldo       0      0.714286
# 12       Lionel Messi       0      0.500000
# 13  Cristiano Ronaldo       1      0.714286
# 14               Xavi       2      1.000000
# 15  Cristiano Ronaldo       1      0.714286
# 16       Lionel Messi       0      0.500000
# 17               Xavi       2      1.000000
# 18       Lionel Messi       2      0.500000
# 19  Cristiano Ronaldo       2      0.714286

# %% [markdown]
# ## 2. Sklearn Category Encoders
# https://contrib.scikit-learn.org/category_encoders/targetencoder.html

# %%
from category_encoders import TargetEncoder
encoder = TargetEncoder()

# %%
df['encoded_sklearn'] = encoder.fit_transform(df['footballers'], df['target'])

# %%
df
# Out:
#           footballers  target  encoded_mean  encoded_sklearn
# 0                Xavi       0      1.000000         0.999933
# 1   Cristiano Ronaldo       0      0.714286         0.714498
# 2                Xavi       1      1.000000         0.999933
# 3                Xavi       1      1.000000         0.999933
# 4        Lionel Messi       0      0.500000         0.514228
# 5                Xavi       1      1.000000         0.999933
# 6                Xavi       1      1.000000         0.999933
# 7   Cristiano Ronaldo       0      0.714286         0.714498
# 8                Xavi       1      1.000000         0.999933
# 9   Cristiano Ronaldo       1      0.714286         0.714498
# 10               Xavi       0      1.000000         0.999933
# 11  Cristiano Ronaldo       0      0.714286         0.714498
# 12       Lionel Messi       0      0.500000         0.514228
# 13  Cristiano Ronaldo       1      0.714286         0.714498
# 14               Xavi       2      1.000000         0.999933
# 15  Cristiano Ronaldo       1      0.714286         0.714498
# 16       Lionel Messi       0      0.500000         0.514228
# 17               Xavi       2      1.000000         0.999933
# 18       Lionel Messi       2      0.500000         0.514228
# 19  Cristiano Ronaldo       2      0.714286         0.714498

# %% [markdown]
# ## 3. Using Probabilities

# %%
categories = df['footballers'].unique()
targets = df['target'].unique()
cat_list = []
for cat in categories:
    aux_dict = {}
    aux_dict['category'] = cat
    aux_df = df[df['footballers'] == cat]
    counts = aux_df['target'].value_counts()
    aux_dict['count'] = sum(counts)
    for t in targets:
        aux_dict['target_' + str(t)] = counts[t] if t in counts.keys() else 0
    cat_list.append(aux_dict)

# %%
cat_list = pd.DataFrame(cat_list)

# %%
for t in targets:
    cat_list['prob_target_' + str(t)] = cat_list['target_' + str(t)] / cat_list['count']

# %%
cat_list
# Out:
#             category  count  target_0  target_1  target_2  prob_target_0  \
# 0               Xavi      9         2         5         2       0.222222
# 1  Cristiano Ronaldo      7         3         3         1       0.428571
# 2       Lionel Messi      4         3         0         1       0.750000
#
#    prob_target_1  prob_target_2
# 0       0.555556       0.222222
# 1       0.428571       0.142857
# 2       0.000000       0.250000

# %%
df = df.join(cat_list.drop(columns = (['count'] + ['target_' + str(t) for t in targets])).set_index('category'), on = 'footballers', how = 'left')
df
# Out:
#           footballers  target  encoded_mean  encoded_sklearn  prob_target_0  \
# 0                Xavi       0      1.000000         0.999933       0.222222
# 1   Cristiano Ronaldo       0      0.714286         0.714498       0.428571
# 2                Xavi       1      1.000000         0.999933       0.222222
# 3                Xavi       1      1.000000         0.999933       0.222222
# 4        Lionel Messi       0      0.500000         0.514228       0.750000
# 5                Xavi       1      1.000000         0.999933       0.222222
# 6                Xavi       1      1.000000         0.999933       0.222222
# 7   Cristiano Ronaldo       0      0.714286         0.714498       0.428571
# 8                Xavi       1      1.000000         0.999933       0.222222
# 9   Cristiano Ronaldo       1      0.714286         0.714498       0.428571
# 10               Xavi       0      1.000000         0.999933       0.222222
# 11  Cristiano Ronaldo       0      0.714286         0.714498       0.428571
# 12       Lionel Messi       0      0.500000         0.514228       0.750000
# 13  Cristiano Ronaldo       1      0.714286         0.714498       0.428571
# 14               Xavi       2      1.000000         0.999933       0.222222
# 15  Cristiano Ronaldo       1      0.714286         0.714498       0.428571
# 16       Lionel Messi       0      0.500000         0.514228       0.750000
# 17               Xavi       2      1.000000         0.999933       0.222222
# 18       Lionel Messi       2      0.500000         0.514228       0.750000
# 19  Cristiano Ronaldo       2      0.714286         0.714498       0.428571
#
#     prob_target_1  prob_target_2
# 0        0.555556       0.222222
# 1        0.428571       0.142857
# 2        0.555556       0.222222
# 3        0.555556       0.222222
# 4        0.000000       0.250000
# 5        0.555556       0.222222
# 6        0.555556       0.222222
# 7        0.428571       0.142857
# 8        0.555556       0.222222
# 9        0.428571       0.142857
# 10       0.555556       0.222222
# 11       0.428571       0.142857
# 12       0.000000       0.250000
# 13       0.428571       0.142857
# 14       0.555556       0.222222
# 15       0.428571       0.142857
# 16       0.000000       0.250000
# 17       0.555556       0.222222
# 18       0.000000       0.250000
# 19       0.428571       0.142857

# %% [markdown]
# ## 4. Using Sklearn

# %%
targets = df['target'].unique()
for t in targets:
    target_aux = df['target'].apply(lambda x: 1 if x == t else 0)
    encoder = TargetEncoder()
    df['sklearn_target_' + str(t)] = encoder.fit_transform(df['footballers'], target_aux)

# %%
df
# Out:
#           footballers  target  encoded_mean  encoded_sklearn  prob_target_0  \
# 0                Xavi       0      1.000000         0.999933       0.222222
# 1   Cristiano Ronaldo       0      0.714286         0.714498       0.428571
# 2                Xavi       1      1.000000         0.999933       0.222222
# 3                Xavi       1      1.000000         0.999933       0.222222
# 4        Lionel Messi       0      0.500000         0.514228       0.750000
# 5                Xavi       1      1.000000         0.999933       0.222222
# 6                Xavi       1      1.000000         0.999933       0.222222
# 7   Cristiano Ronaldo       0      0.714286         0.714498       0.428571
# 8                Xavi       1      1.000000         0.999933       0.222222
# 9   Cristiano Ronaldo       1      0.714286         0.714498       0.428571
# 10               Xavi       0      1.000000         0.999933       0.222222
# 11  Cristiano Ronaldo       0      0.714286         0.714498       0.428571
# 12       Lionel Messi       0      0.500000         0.514228       0.750000
# 13  Cristiano Ronaldo       1      0.714286         0.714498       0.428571
# 14               Xavi       2      1.000000         0.999933       0.222222
# 15  Cristiano Ronaldo       1      0.714286         0.714498       0.428571
# 16       Lionel Messi       0      0.500000         0.514228       0.750000
# 17               Xavi       2      1.000000         0.999933       0.222222
# 18       Lionel Messi       2      0.500000         0.514228       0.750000
# 19  Cristiano Ronaldo       2      0.714286         0.714498       0.428571
#
#     prob_target_1  prob_target_2  sklearn_target_0  sklearn_target_1  \
# 0        0.555556       0.222222          0.222282          0.555503
# 1        0.428571       0.142857          0.428501          0.428501
# 2        0.555556       0.222222          0.222282          0.555503
# 3        0.555556       0.222222          0.222282          0.555503
# 4        0.000000       0.250000          0.733401          0.018970
# 5        0.555556       0.222222          0.222282          0.555503
# 6        0.555556       0.222222          0.222282          0.555503
# 7        0.428571       0.142857          0.428501          0.428501
# 8        0.555556       0.222222          0.222282          0.555503
# 9        0.428571       0.142857          0.428501          0.428501
# 10       0.555556       0.222222          0.222282          0.555503
# 11       0.428571       0.142857          0.428501          0.428501
# 12       0.000000       0.250000          0.733401          0.018970
# 13       0.428571       0.142857          0.428501          0.428501
# 14       0.555556       0.222222          0.222282          0.555503
# 15       0.428571       0.142857          0.428501          0.428501
# 16       0.000000       0.250000          0.733401          0.018970
# 17       0.555556       0.222222          0.222282          0.555503
# 18       0.000000       0.250000          0.733401          0.018970
# 19       0.428571       0.142857          0.428501          0.428501
#
#     sklearn_target_2
# 0           0.222215
# 1           0.142998
# 2           0.222215
# 3           0.222215
# 4           0.247629
# 5           0.222215
# 6           0.222215
# 7           0.142998
# 8           0.222215
# 9           0.142998
# 10          0.222215
# 11          0.142998
# 12          0.247629
# 13          0.142998
# 14          0.222215
# 15          0.142998
# 16          0.247629
# 17          0.222215
# 18          0.247629
# 19          0.142998

# %% [markdown]
# ## 5. Using Sklearn Mean encoding

# %%
targets = df['target'].unique()
for t in targets:
    df['target_' + str(t)] = df['target'].apply(lambda x: 1 if x == t else 0)
    stats = df['target_' + str(t)].groupby(df['footballers']).agg(['mean'])
    df = df.join(stats, on = 'footballers', how = 'left').rename(columns = {'mean'  : 'encoded_mean_target_' + str(t)})
    df = df.drop(columns = ['target_' + str(t)])

# %%
df
# Out:
#           footballers  target  encoded_mean  encoded_sklearn  prob_target_0  \
# 0                Xavi       0      1.000000         0.999933       0.222222
# 1   Cristiano Ronaldo       0      0.714286         0.714498       0.428571
# 2                Xavi       1      1.000000         0.999933       0.222222
# 3                Xavi       1      1.000000         0.999933       0.222222
# 4        Lionel Messi       0      0.500000         0.514228       0.750000
# 5                Xavi       1      1.000000         0.999933       0.222222
# 6                Xavi       1      1.000000         0.999933       0.222222
# 7   Cristiano Ronaldo       0      0.714286         0.714498       0.428571
# 8                Xavi       1      1.000000         0.999933       0.222222
# 9   Cristiano Ronaldo       1      0.714286         0.714498       0.428571
# 10               Xavi       0      1.000000         0.999933       0.222222
# 11  Cristiano Ronaldo       0      0.714286         0.714498       0.428571
# 12       Lionel Messi       0      0.500000         0.514228       0.750000
# 13  Cristiano Ronaldo       1      0.714286         0.714498       0.428571
# 14               Xavi       2      1.000000         0.999933       0.222222
# 15  Cristiano Ronaldo       1      0.714286         0.714498       0.428571
# 16       Lionel Messi       0      0.500000         0.514228       0.750000
# 17               Xavi       2      1.000000         0.999933       0.222222
# 18       Lionel Messi       2      0.500000         0.514228       0.750000
# 19  Cristiano Ronaldo       2      0.714286         0.714498       0.428571
#
#     prob_target_1  prob_target_2  sklearn_target_0  sklearn_target_1  \
# 0        0.555556       0.222222          0.222282          0.555503
# 1        0.428571       0.142857          0.428501          0.428501
# 2        0.555556       0.222222          0.222282          0.555503
# 3        0.555556       0.222222          0.222282          0.555503
# 4        0.000000       0.250000          0.733401          0.018970
# 5        0.555556       0.222222          0.222282          0.555503
# 6        0.555556       0.222222          0.222282          0.555503
# 7        0.428571       0.142857          0.428501          0.428501
# 8        0.555556       0.222222          0.222282          0.555503
# 9        0.428571       0.142857          0.428501          0.428501
# 10       0.555556       0.222222          0.222282          0.555503
# 11       0.428571       0.142857          0.428501          0.428501
# 12       0.000000       0.250000          0.733401          0.018970
# 13       0.428571       0.142857          0.428501          0.428501
# 14       0.555556       0.222222          0.222282          0.555503
# 15       0.428571       0.142857          0.428501          0.428501
# 16       0.000000       0.250000          0.733401          0.018970
# 17       0.555556       0.222222          0.222282          0.555503
# 18       0.000000       0.250000          0.733401          0.018970
# 19       0.428571       0.142857          0.428501          0.428501
#
#     sklearn_target_2  encoded_mean_target_0  encoded_mean_target_1  \
# 0           0.222215               0.222222               0.555556
# 1           0.142998               0.428571               0.428571
# 2           0.222215               0.222222               0.555556
# 3           0.222215               0.222222               0.555556
# 4           0.247629               0.750000               0.000000
# 5           0.222215               0.222222               0.555556
# 6           0.222215               0.222222               0.555556
# 7           0.142998               0.428571               0.428571
# 8           0.222215               0.222222               0.555556
# 9           0.142998               0.428571               0.428571
# 10          0.222215               0.222222               0.555556
# 11          0.142998               0.428571               0.428571
# 12          0.247629               0.750000               0.000000
# 13          0.142998               0.428571               0.428571
# 14          0.222215               0.222222               0.555556
# 15          0.142998               0.428571               0.428571
# 16          0.247629               0.750000               0.000000
# 17          0.222215               0.222222               0.555556
# 18          0.247629               0.750000               0.000000
# 19          0.142998               0.428571               0.428571
#
#     encoded_mean_target_2
# 0                0.222222
# 1                0.142857
# 2                0.222222
# 3                0.222222
# 4                0.250000
# 5                0.222222
# 6                0.222222
# 7                0.142857
# 8                0.222222
# 9                0.142857
# 10               0.222222
# 11               0.142857
# 12               0.250000
# 13               0.142857
# 14               0.222222
# 15               0.142857
# 16               0.250000
# 17               0.222222
# 18               0.250000
# 19               0.142857
